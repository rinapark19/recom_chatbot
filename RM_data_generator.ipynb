# %%
# !pip install openai

import os
import openai

# %%
openai.api_key = "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"

# %%
model = 'gpt-3.5-turbo'
query = '초등학생이 읽을 만한 책 추천해 줘'
messages = [{
    "role": "system",
    "content": "You are book recommender system"
}, {
    "role": "user",
    "content": query
}]

response = openai.ChatCompletion.create(model=model, messages=messages)
answer = response['choices'][0]['message']['content']
print(answer)

# %%
# !pip install langchain

# %%
os.environ['OPENAI_API_KEY'] = "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"

# %%
from langchain.llms import OpenAI
llm1 = OpenAI(model_name="text-davinci-003", temperature=0.9)
llm1("초등학생이 읽을 만한 책 추천해 줘")
# Out:
# '\n\n - 김종우의 나는 조금 다르다\n - 보스바디의 보스바디의 나는 똑바로 살아가기\n - 꼬마 마린 유니버스의 두번째 바다\n - 루시앙 고브레의 타잔과 바퀴벌레\n - 스티븐 코코넛트의 사과 트리의 비밀\n - 김연경의 사과 나무 속의 이'

# %%
llm2 = OpenAI(model_name="gpt-3.5-turbo", temperature=0.9)
llm2("초등학생이 읽을 만한 책 추천해 줘")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:179: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:748: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# "1. '돌이킬 수 없는 약속' - 정혜영 작가\n2. '반지의 제왕' - J.R.R. 톨킨 작가\n3. '해리 포터' 시리즈 - J.K. 롤링 작가\n4. '참새들이 노래하는 날' - 김난도 작가\n5. '컬러모피즘 - 빨간 점의 탄생' - 이세돌 작가\n6. '바다 위의 집' - 이효석 작가\n7. '마법천자문' 시리즈 - 조형래 작가\n8. '왕초보 달리기' - 정환이 작가\n9. '손뼉 치는 대로 행진하는 집' - 김수현 작가\n10. '두근두근 내 인생' 시리즈 - 박원숙 작가"

# %%
def get_responses(prompt:str):
  data = {}
  llm1 = OpenAI(model_name="text-davinci-003", temperature=0.9)
  llm2 = OpenAI(model_name="gpt-3.5-turbo", temperature=0.9)
  data['prompt'] = prompt
  data['response1'] = llm1(prompt)
  data['response2'] = llm2(prompt)
  return data

# %%
data = get_responses("초등학생이 읽을 만한 책 추천해 줘")
data
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:179: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:748: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# {'prompt': '초등학생이 읽을 만한 책 추천해 줘',
#  'response1': '\n\n1. 《노을만 녹는 숲》 by 한강\n2. 《숲 호수는 우리들만의 공간》 by 신혜원\n3. 《루쥬는 나비 같이》 by 박해숙\n4. 《신비한 구두쇠의 소문》 by 윤광연\n5. 《고양이 파파의 색다른 이야기》 by 브랭클린 실버만\n6. 《숲 속의 거미》 by ',
#  'response2': "1. '어린 왕자' - 생텍쥐베리\n2. '밀림의 왕자' - 데이비드 호크니\n3. '호두까기 인형' - E.T.A. 호프만\n4. '꼬마 마법사의 학교' - 레이몬드 E. 페이스터\n5. '나니아 연대기' 시리즈 - C.S. 루이스\n6. '마법의 숲' - 유진 트리바우터\n7. '도깨비숲' - 마리 셸리\n8. '부엉이와 쥐돌이' - 알렉산더 펠리시옹\n9. '운명을 바꾼 사과' - 사이먼 콜스\n10. '올리버 트위스트' - 찰스 디킨스"}

# %%
type(data)
# Out:
# dict

# %%
def choose(number):
  if number == 1:
    data['chosen'] = data.pop('response1')
    data['rejected'] = data.pop('response2')

  elif number == 2:
    data['chosen'] = data.pop('response2')
    data['rejected'] = data.pop('response1')

# %%
choose(2)

# %%
rm_dataset = {}
rm_dataset.update(data)

# %%
rm_dataset
# Out:
# {'prompt': '초등학생이 읽을 만한 책 추천해 줘',
#  'chosen': "1. '어린 왕자' - 생텍쥐베리\n2. '밀림의 왕자' - 데이비드 호크니\n3. '호두까기 인형' - E.T.A. 호프만\n4. '꼬마 마법사의 학교' - 레이몬드 E. 페이스터\n5. '나니아 연대기' 시리즈 - C.S. 루이스\n6. '마법의 숲' - 유진 트리바우터\n7. '도깨비숲' - 마리 셸리\n8. '부엉이와 쥐돌이' - 알렉산더 펠리시옹\n9. '운명을 바꾼 사과' - 사이먼 콜스\n10. '올리버 트위스트' - 찰스 디킨스",
#  'rejected': '\n\n1. 《노을만 녹는 숲》 by 한강\n2. 《숲 호수는 우리들만의 공간》 by 신혜원\n3. 《루쥬는 나비 같이》 by 박해숙\n4. 《신비한 구두쇠의 소문》 by 윤광연\n5. 《고양이 파파의 색다른 이야기》 by 브랭클린 실버만\n6. 《숲 속의 거미》 by '}
